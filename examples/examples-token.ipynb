# %%
import getpass
import cordra
from lucenequerybuilder import Q
from io import StringIO
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Cordra Host Information

# %%
host = "https://localhost:8443/"
obj_type = "Document"

# %% [markdown]
# # User Login Details

# %%
username = "testuser1"
password = getpass.getpass()
# Out:
# ········

# %% [markdown]
# # Get Auth Token

# %%
token = cordra.create_token(host,username,password,verify=False)
token
# Out:
# {'access_token': '1otmql2b9zf9i6d6ob3cc0rub',
#  'token_type': 'Bearer',
#  'active': True,
#  'userId': 'test/04df9d913013b0680e93',
#  'username': 'testuser1'}

# %% [markdown]
# # Create two similar objects

# %%
file_1 = "example-data.csv"
payloads = {'p1': (file_1, open(file_1,'rb'))}

obj_1 = dict()
obj_1["name"] = "example 1"
obj_1["description"] = "an example of metadata for CSV payload"
obj_1["author"] = "John"

my_acl = dict()
my_acl["readers"] = ["public"]

response = cordra.create_object(
    host,
    obj_1,
    obj_type,
    token=token,
    verify=False,
    acls=my_acl,
    payloads=payloads)
response
# Out:
# {'id': 'test/41021935e7233d777e52',
#  'name': 'example 1',
#  'description': 'an example of metadata for CSV payload',
#  'author': 'John'}

# %%
file_2 = "example-data.csv"
payloads = {'p1': (file_2, open(file_2,'rb'))}

obj_2 = dict()
obj_2["name"] = "example 2"
obj_2["description"] = "another example of metadata for CSV payload"
obj_2["author"] = "Tim"

my_acl = dict()
my_acl["readers"] = ["public"]

response = cordra.create_object(
    host,
    obj_2,
    obj_type,
    token=token,
    verify=False,
    acls=my_acl,
    payloads=payloads)
response
# Out:
# {'id': 'test/b584ba2edc495d16a0e8',
#  'name': 'example 2',
#  'description': 'another example of metadata for CSV payload',
#  'author': 'Tim'}

# %% [markdown]
# # Query objects

# %% [markdown]
# ## Full text query example

# %%
q = Q('metadata')
my_results = cordra.find_objects(host,str(q),verify=False,full=True)
my_results
# Out:
# {'pageNum': 0,
#  'pageSize': -1,
#  'size': 19,
#  'results': [{'id': 'test/f1f0188d7e74ce2e9b39',
#    'type': 'Document',
#    'content': {'id': 'test/f1f0188d7e74ce2e9b39',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631522038838,
#     'createdBy': 'test/dd860110a62b19214c4e',
#     'modifiedOn': 1631522038838,
#     'modifiedBy': 'test/dd860110a62b19214c4e',
#     'txnId': 1631522038839001},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/bc2bf80fc64a79484422',
#    'type': 'Document',
#    'content': {'id': 'test/bc2bf80fc64a79484422',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631524774055,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631524774055,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631524774055028},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/dbde3a33a2a98e30f9b1',
#    'type': 'Document',
#    'content': {'id': 'test/dbde3a33a2a98e30f9b1',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631524446991,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631524446991,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631524446991022},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/b599a8b2c7a46e4380cf',
#    'type': 'Document',
#    'content': {'id': 'test/b599a8b2c7a46e4380cf',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631525174446,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631525174446,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631525174446032},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/36c0c6de94202a76c48d',
#    'type': 'Document',
#    'content': {'id': 'test/36c0c6de94202a76c48d',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631524476571,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631524476571,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631524476571024},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/76f493bfe4dee7e69dd8',
#    'type': 'Document',
#    'content': {'id': 'test/76f493bfe4dee7e69dd8',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631523864129,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631523864129,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631523864130018},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/31e38aab3413574e553a',
#    'type': 'Document',
#    'content': {'id': 'test/31e38aab3413574e553a',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631522683959,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631522683959,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631522683959015},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/26ef6f8f113c93201aab',
#    'type': 'Document',
#    'content': {'id': 'test/26ef6f8f113c93201aab',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631524159133,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631524159133,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631524159133020},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/2924864f0ca6b1dc49ec',
#    'type': 'Document',
#    'content': {'id': 'test/2924864f0ca6b1dc49ec',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631522663349,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631522663349,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631522663349010},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/5a2bbb1198b224e6f85a',
#    'type': 'Document',
#    'content': {'id': 'test/5a2bbb1198b224e6f85a',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631525266367,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631525266367,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631525266367036},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/07cc494e735ea4b8e67e',
#    'type': 'Document',
#    'content': {'id': 'test/07cc494e735ea4b8e67e',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631525385012,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631525385012,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631525385012040},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/ae1bbaed41ada5524981',
#    'type': 'Document',
#    'content': {'id': 'test/ae1bbaed41ada5524981',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631534373420,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631534373420,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631534373420044},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/aef168409120ada825c2',
#    'type': 'Document',
#    'content': {'id': 'test/aef168409120ada825c2',
#     'name': 'example 2',
#     'description': 'another example of metadata for CSV payload',
#     'author': 'Tim'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631534373459,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631534373459,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631534373459045},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/393a3e2e7590d9f0f891',
#    'type': 'Document',
#    'content': {'id': 'test/393a3e2e7590d9f0f891',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233084831,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233084831,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233084834000},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/bf2229bfa175ef753a77',
#    'type': 'Document',
#    'content': {'id': 'test/bf2229bfa175ef753a77',
#     'name': 'example 2',
#     'description': 'another example of metadata for CSV payload',
#     'author': 'Tim'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233085405,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233085405,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233085405001},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/2276a9aa4decebc36b7d',
#    'type': 'Document',
#    'content': {'id': 'test/2276a9aa4decebc36b7d',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233324783,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233324783,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233324783004},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/4ea37787213598d1ef90',
#    'type': 'Document',
#    'content': {'id': 'test/4ea37787213598d1ef90',
#     'name': 'example 2',
#     'description': 'another example of metadata for CSV payload',
#     'author': 'Tim'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233324833,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233324833,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233324833005},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/41021935e7233d777e52',
#    'type': 'Document',
#    'content': {'id': 'test/41021935e7233d777e52',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233387817,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233387817,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233387818008},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/b584ba2edc495d16a0e8',
#    'type': 'Document',
#    'content': {'id': 'test/b584ba2edc495d16a0e8',
#     'name': 'example 2',
#     'description': 'another example of metadata for CSV payload',
#     'author': 'Tim'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233387924,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233387924,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233387925009},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]}]}

# %% [markdown]
# ## Field query examples

# %%
q = Q('/author','John')
my_results = cordra.find_objects(host,str(q),verify=False,full=True)
obj_id_1 = my_results["results"][0]["id"]
my_results
# Out:
# {'pageNum': 0,
#  'pageSize': -1,
#  'size': 15,
#  'results': [{'id': 'test/f1f0188d7e74ce2e9b39',
#    'type': 'Document',
#    'content': {'id': 'test/f1f0188d7e74ce2e9b39',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631522038838,
#     'createdBy': 'test/dd860110a62b19214c4e',
#     'modifiedOn': 1631522038838,
#     'modifiedBy': 'test/dd860110a62b19214c4e',
#     'txnId': 1631522038839001},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/bc2bf80fc64a79484422',
#    'type': 'Document',
#    'content': {'id': 'test/bc2bf80fc64a79484422',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631524774055,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631524774055,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631524774055028},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/dbde3a33a2a98e30f9b1',
#    'type': 'Document',
#    'content': {'id': 'test/dbde3a33a2a98e30f9b1',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631524446991,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631524446991,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631524446991022},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/b599a8b2c7a46e4380cf',
#    'type': 'Document',
#    'content': {'id': 'test/b599a8b2c7a46e4380cf',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631525174446,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631525174446,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631525174446032},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/36c0c6de94202a76c48d',
#    'type': 'Document',
#    'content': {'id': 'test/36c0c6de94202a76c48d',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631524476571,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631524476571,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631524476571024},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/76f493bfe4dee7e69dd8',
#    'type': 'Document',
#    'content': {'id': 'test/76f493bfe4dee7e69dd8',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631523864129,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631523864129,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631523864130018},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/31e38aab3413574e553a',
#    'type': 'Document',
#    'content': {'id': 'test/31e38aab3413574e553a',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631522683959,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631522683959,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631522683959015},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/26ef6f8f113c93201aab',
#    'type': 'Document',
#    'content': {'id': 'test/26ef6f8f113c93201aab',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631524159133,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631524159133,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631524159133020},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/2924864f0ca6b1dc49ec',
#    'type': 'Document',
#    'content': {'id': 'test/2924864f0ca6b1dc49ec',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631522663349,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631522663349,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631522663349010},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/5a2bbb1198b224e6f85a',
#    'type': 'Document',
#    'content': {'id': 'test/5a2bbb1198b224e6f85a',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631525266367,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631525266367,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631525266367036},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/07cc494e735ea4b8e67e',
#    'type': 'Document',
#    'content': {'id': 'test/07cc494e735ea4b8e67e',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631525385012,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631525385012,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631525385012040},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/ae1bbaed41ada5524981',
#    'type': 'Document',
#    'content': {'id': 'test/ae1bbaed41ada5524981',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631534373420,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631534373420,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631534373420044},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/393a3e2e7590d9f0f891',
#    'type': 'Document',
#    'content': {'id': 'test/393a3e2e7590d9f0f891',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233084831,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233084831,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233084834000},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/2276a9aa4decebc36b7d',
#    'type': 'Document',
#    'content': {'id': 'test/2276a9aa4decebc36b7d',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233324783,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233324783,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233324783004},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/41021935e7233d777e52',
#    'type': 'Document',
#    'content': {'id': 'test/41021935e7233d777e52',
#     'name': 'example 1',
#     'description': 'an example of metadata for CSV payload',
#     'author': 'John'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233387817,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233387817,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233387818008},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]}]}

# %%
q = Q('/author','Tim')
my_results = cordra.find_objects(host,str(q),verify=False,full=True)
obj_id_2 = my_results["results"][0]["id"]
my_results
# Out:
# {'pageNum': 0,
#  'pageSize': -1,
#  'size': 4,
#  'results': [{'id': 'test/aef168409120ada825c2',
#    'type': 'Document',
#    'content': {'id': 'test/aef168409120ada825c2',
#     'name': 'example 2',
#     'description': 'another example of metadata for CSV payload',
#     'author': 'Tim'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1631534373459,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1631534373459,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1631534373459045},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/bf2229bfa175ef753a77',
#    'type': 'Document',
#    'content': {'id': 'test/bf2229bfa175ef753a77',
#     'name': 'example 2',
#     'description': 'another example of metadata for CSV payload',
#     'author': 'Tim'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233085405,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233085405,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233085405001},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/4ea37787213598d1ef90',
#    'type': 'Document',
#    'content': {'id': 'test/4ea37787213598d1ef90',
#     'name': 'example 2',
#     'description': 'another example of metadata for CSV payload',
#     'author': 'Tim'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233324833,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233324833,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233324833005},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]},
#   {'id': 'test/b584ba2edc495d16a0e8',
#    'type': 'Document',
#    'content': {'id': 'test/b584ba2edc495d16a0e8',
#     'name': 'example 2',
#     'description': 'another example of metadata for CSV payload',
#     'author': 'Tim'},
#    'acl': {'readers': ['public']},
#    'metadata': {'createdOn': 1632233387924,
#     'createdBy': 'test/04df9d913013b0680e93',
#     'modifiedOn': 1632233387924,
#     'modifiedBy': 'test/04df9d913013b0680e93',
#     'txnId': 1632233387925009},
#    'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]}]}

# %% [markdown]
# # Read objects

# %%
obj_id_2
# Out:
# 'test/aef168409120ada825c2'

# %%
my_obj = cordra.read_object(host,obj_id_2,verify=False)
my_obj
# Out:
# {'id': 'test/aef168409120ada825c2',
#  'name': 'example 2',
#  'description': 'another example of metadata for CSV payload',
#  'author': 'Tim'}

# %%
my_obj = cordra.read_object(host,obj_id_2,verify=False,full=True)
my_obj
# Out:
# {'id': 'test/aef168409120ada825c2',
#  'type': 'Document',
#  'content': {'id': 'test/aef168409120ada825c2',
#   'name': 'example 2',
#   'description': 'another example of metadata for CSV payload',
#   'author': 'Tim'},
#  'acl': {'readers': ['public']},
#  'metadata': {'createdOn': 1631534373459,
#   'createdBy': 'test/04df9d913013b0680e93',
#   'modifiedOn': 1631534373459,
#   'modifiedBy': 'test/04df9d913013b0680e93',
#   'txnId': 1631534373459045},
#  'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]}

# %%
obj_payload_name = my_obj["payloads"][0]["name"]
obj_payload_name
# Out:
# 'p1'

# %%
payload = cordra.read_payload(host,obj_id_2,obj_payload_name,verify=False)
payload.decode('utf-8')
# Out:
# '\ufeff"SAM0","SAM1"\r\n1.00,2.302389071\r\n2.00,3.71503899\r\n3.00,9.426125622\r\n4.00,11.34529125\r\n5.00,11.87704484\r\n6.00,19.01325695\r\n7.00,21.52353652\r\n8.00,28.28670056\r\n9.00,29.55737761\r\n10.00,25.89582707\r\n11.00,31.57982065\r\n12.00,36.02452105\r\n13.00,39.47686412\r\n14.00,44.41192202\r\n15.00,43.36098819\r\n16.00,48.61525381\r\n17.00,53.91222295\r\n18.00,54.28420278\r\n19.00,53.1378195\r\n20.00,55.88015939'

# %%
df = pd.read_csv(StringIO(payload.decode('utf-8')))
df
# Out:
#     SAM0       SAM1
# 0    1.0   2.302389
# 1    2.0   3.715039
# 2    3.0   9.426126
# 3    4.0  11.345291
# 4    5.0  11.877045
# 5    6.0  19.013257
# 6    7.0  21.523537
# 7    8.0  28.286701
# 8    9.0  29.557378
# 9   10.0  25.895827
# 10  11.0  31.579821
# 11  12.0  36.024521
# 12  13.0  39.476864
# 13  14.0  44.411922
# 14  15.0  43.360988
# 15  16.0  48.615254
# 16  17.0  53.912223
# 17  18.0  54.284203
# 18  19.0  53.137819
# 19  20.0  55.880159

# %%
df.plot.scatter(x='SAM0', y='SAM1')
plt.show()

# %% [markdown]
# # Update Objects
#
# This also demonstrates the use of "Dry Run". During a "Dry Run", Cordra not actually create/update the object. Cordra will return results as if object had been created/updated.

# %% [markdown]
# ## Update part of the object JSON
#
# payloads not affected

# %%
response = cordra.update_object(
    host,
    obj_id_2,
    obj_json="I really need to write a better description for my data.",
    jsonPointer="/description",
    token=token,
    verify=False,
    dryRun=True,
    full=True)
response
# Out:
# {'id': 'test/aef168409120ada825c2',
#  'type': 'Document',
#  'content': {'id': 'test/aef168409120ada825c2',
#   'name': 'example 2',
#   'description': 'I really need to write a better description for my data.',
#   'author': 'Tim'},
#  'acl': {'readers': ['public']},
#  'metadata': {'createdOn': 1631534373459,
#   'createdBy': 'test/04df9d913013b0680e93',
#   'modifiedOn': 1632233388613,
#   'modifiedBy': 'test/04df9d913013b0680e93',
#   'txnId': 1631534373459045},
#  'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]}

# %% [markdown]
# ## Update all of the object JSON
#
# payloads not affected

# %%
response = cordra.update_object(
    host,
    obj_id_2,
    obj_json={"SAM1":"Level of CXCR4 expression"},
    token=token,
    verify=False,
    dryRun=True,
    full=True)
response
# Out:
# {'id': 'test/aef168409120ada825c2',
#  'type': 'Document',
#  'content': {'id': 'test/aef168409120ada825c2',
#   'SAM1': 'Level of CXCR4 expression'},
#  'acl': {'readers': ['public']},
#  'metadata': {'createdOn': 1631534373459,
#   'createdBy': 'test/04df9d913013b0680e93',
#   'modifiedOn': 1632233388638,
#   'modifiedBy': 'test/04df9d913013b0680e93',
#   'txnId': 1631534373459045},
#  'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]}

# %% [markdown]
# ## Update just ACLs
#
# payloads not affected

# %%
response = cordra.update_object(
    host,
    obj_id_2,
    acls={"readers":None,"writers":None},
    token=token,
    verify=False,
    full=True)
response
# Out:
# {}

# %%
# this should return a 401 error

try:
    my_obj = cordra.read_object(host,obj_id_2,verify=False,full=True)
except Exception as e: 
    print(e)
# Out:
# 401 Client Error: Unauthorized for url: https://localhost:8443/objects/test/aef168409120ada825c2?full=True

# %%
my_obj = cordra.read_object(host,obj_id_2,token=token,verify=False,full=True)
my_obj
# Out:
# {'id': 'test/aef168409120ada825c2',
#  'type': 'Document',
#  'content': {'id': 'test/aef168409120ada825c2',
#   'name': 'example 2',
#   'description': 'another example of metadata for CSV payload',
#   'author': 'Tim'},
#  'acl': {},
#  'metadata': {'createdOn': 1631534373459,
#   'createdBy': 'test/04df9d913013b0680e93',
#   'modifiedOn': 1632233388669,
#   'modifiedBy': 'test/04df9d913013b0680e93',
#   'txnId': 1632233388664010},
#  'payloads': [{'name': 'p1', 'filename': 'example-data.csv', 'size': 385}]}

# %% [markdown]
# # Delete objects

# %%
response = cordra.delete_object(host,obj_id_2,token=token,verify=False)
response
# Out:
# {}

# %% [markdown]
# # Delete Token

# %%
r =  cordra.delete_token(host,token,verify=False)
r
# Out:
# {'active': False}
